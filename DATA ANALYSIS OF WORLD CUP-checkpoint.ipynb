# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ft = pd.read_csv(r"C:\Users\USER\Documents\22-10 wc data.csv")

# %%
ft
# Out:
#      Position         Team  Games Played  Win  Draw  Loss  Goals For  \
# 0           1    Argentina             7    6     0     1         15
# 1           2       France             7    5     0     2         16
# 2           3      Croatia             7    4     2     1          8
# 3           4      Morocco             7    4     1     2          6
# 4           5      England             5    3     1     1         13
# ..        ...          ...           ...  ...   ...   ...        ...
# 123        28      Algeria             3    0     1     2          0
# 124        29       France             3    0     1     2          1
# 125        30     Honduras             3    0     1     2          0
# 126        31     Cameroon             3    0     0     3          2
# 127        32  North Korea             3    0     0     3          1
#
#      Goals Against  Goal Difference  Points  year
# 0                8                7      18  2022
# ...

# %%
ft.head(2)
# Out:
#    Position       Team  Games Played  Win  Draw  Loss  Goals For  \
# 0         1  Argentina             7    6     0     1         15
# 1         2     France             7    5     0     2         16
#
#    Goals Against  Goal Difference  Points  year
# 0              8                7      18  2022
# 1              8                8      15  2022

# %%
ft.isnull().sum()
# Out:
# Position           0
# Team               0
# Games Played       0
# Win                0
# Draw               0
# Loss               0
# Goals For          0
# Goals Against      0
# Goal Difference    0
# Points             0
# year               0
# dtype: int64

# %% [markdown]
# # Goals scored over 13 in a single campaign

# %%
ft[ft['Goals For']>13]
# Out:
#     Position         Team  Games Played  Win  Draw  Loss  Goals For  \
# 0          1    Argentina             7    6     0     1         15
# 1          2       France             7    5     0     2         16
# 32         1       France             7    6     1     0         14
# 33         2      Croatia             7    4     2     1         14
# 34         3      Belgium             7    6     0     1         16
# 64         1      Germany             7    6     1     0         18
# 66         3  Netherlands             7    5     2     0         15
# 98         3      Germany             7    5     0     2         16
#
#     Goals Against  Goal Difference  Points  year
# 0               8                7      18  2022
# 1               8                8      15  2022
# 32              6                8      19  2018
# 33              9                5      14  2018
# 34              6               10      18  2018
# 64              4               14      19  2014
# ...

# %% [markdown]
# # Goal difference over 10 in a single campaign

# %%
ft[ft['Goal Difference']>10]
# Out:
#     Position         Team  Games Played  Win  Draw  Loss  Goals For  \
# 64         1      Germany             7    6     1     0         18
# 66         3  Netherlands             7    5     2     0         15
# 98         3      Germany             7    5     0     2         16
#
#     Goals Against  Goal Difference  Points  year
# 64              4               14      19  2014
# 66              4               11      17  2014
# 98              5               11      15  2010

# %% [markdown]
# # Points over 17 in a single campaign

# %%
ft[ft['Points']>17]
# Out:
#     Position         Team  Games Played  Win  Draw  Loss  Goals For  \
# 0          1    Argentina             7    6     0     1         15
# 32         1       France             7    6     1     0         14
# 34         3      Belgium             7    6     0     1         16
# 64         1      Germany             7    6     1     0         18
# 96         1        Spain             7    6     0     1          8
# 97         2  Netherlands             7    6     0     1         12
#
#     Goals Against  Goal Difference  Points  year
# 0               8                7      18  2022
# 32              6                8      19  2018
# 34              6               10      18  2018
# 64              4               14      19  2014
# 96              2                6      18  2010
# 97              6                6      18  2010

# %% [markdown]
# # Goal for vs points scatterplot

# %%
sns.scatterplot(x='Goals For', y='Points', data=ft)
plt.title('Goals For vs Points')
plt.show()

# %%
argentina_data = ft[ft['Team'] == 'Argentina']

# %%
print(argentina_data.describe())
# Out:
#         Position  Games Played       Win     Draw  Loss  Goals For  \
# count   4.000000          4.00  4.000000  4.00000  4.00    4.00000
# mean    5.750000          5.75  4.000000  0.50000  1.25    9.75000
# std     6.396614          1.50  2.160247  0.57735  0.50    3.86221
# min     1.000000          4.00  1.000000  0.00000  1.00    6.00000
# 25%     1.750000          4.75  3.250000  0.00000  1.00    7.50000
# 50%     3.500000          6.00  4.500000  0.50000  1.00    9.00000
# 75%     7.500000          7.00  5.250000  1.00000  1.25   11.25000
# max    15.000000          7.00  6.000000  1.00000  2.00   15.00000
#
#        Goals Against  Goal Difference     Points         year
# count       4.000000         4.000000   4.000000     4.000000
# mean        6.750000         3.000000  12.500000  2016.000000
# std         2.217356         4.242641   6.191392     5.163978
# min         4.000000        -3.000000   4.000000  2010.000000
# ...

# %% [markdown]
# # Argentinas record about goals

# %%
sns.lineplot(x='year', y='Goals For', data=argentina_data, label='Goals For')
sns.lineplot(x='year', y='Goals Against', data=argentina_data, label='Goals Against')
plt.title('Argentina Goals Over Years')
plt.legend()
plt.show()

# %% [markdown]
# # Argentinas Win percentage

# %%
argentina_data['Win Percentage'] = argentina_data['Win'] / argentina_data['Games Played'] * 100
print(argentina_data[['year', 'Win Percentage']])
# Out:
#      year  Win Percentage
# 0    2022       85.714286
# 46   2018       25.000000
# 65   2014       71.428571
# 100  2010       80.000000
# C:\Users\USER\AppData\Local\Temp\ipykernel_13300\716072498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   argentina_data['Win Percentage'] = argentina_data['Win'] / argentina_data['Games Played'] * 100

# %% [markdown]
# # Argentina's average goals for vs goal against

# %%
argentina_data['Avg Goals For'] = argentina_data['Goals For'] / argentina_data['Games Played']
argentina_data['Avg Goals Against'] = argentina_data['Goals Against'] / argentina_data['Games Played']
print(argentina_data[['year', 'Avg Goals For', 'Avg Goals Against']])
# Out:
#      year  Avg Goals For  Avg Goals Against
# 0    2022       2.142857           1.142857
# 46   2018       1.500000           2.250000
# 65   2014       1.142857           0.571429
# 100  2010       2.000000           1.200000
# C:\Users\USER\AppData\Local\Temp\ipykernel_13300\1762129570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   argentina_data['Avg Goals For'] = argentina_data['Goals For'] / argentina_data['Games Played']
# C:\Users\USER\AppData\Local\Temp\ipykernel_13300\1762129570.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.lineplot(x='year', y='Points', data=argentina_data)
plt.title('Argentina Performance Over Years')
plt.show()

# %%
teams_to_compare = ['Germany', 'Spain', 'France', 'England']
data_for_comparison = ft[ft['Team'].isin(teams_to_compare)]

# %% [markdown]
# # Comparison between france, england, spain and germany

# %%
sns.lineplot(x='year', y='Points', hue='Team', data=data_for_comparison)
plt.title('Performance Comparison Over Years')
plt.show()

# %%
england_data = ft[ft['Team'] == 'England']

# %% [markdown]
# # Englands record

# %%
sns.lineplot(x='year', y='Goals For', data=england_data, label='Goals For')
sns.lineplot(x='year', y='Goals Against', data=england_data, label='Goals Against')
plt.title('England Goals Over Years')
plt.legend()
plt.show()

# %% [markdown]
# # Three lions win percentage over years

# %%
england_data['Win Percentage'] = england_data['Win'] / england_data['Games Played'] * 100
print(england_data[['year', 'Win Percentage']])
# Out:
#      year  Win Percentage
# 4    2022       60.000000
# 35   2018       42.857143
# 89   2014        0.000000
# 108  2010       25.000000
# C:\Users\USER\AppData\Local\Temp\ipykernel_13300\3182234610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   england_data['Win Percentage'] = england_data['Win'] / england_data['Games Played'] * 100

# %%
sns.lineplot(x='year', y='Points', data=england_data)
plt.title('Englands Performance Over Years')
plt.show()

# %%
germany_data = ft[ft['Team'] == 'Germany']
brazil_data = ft[ft['Team'] == 'Brazil']
uruguay_data = ft[ft['Team'] == 'Uruguay']

# %%
england_data['Win Percentage'] = england_data['Win'] / england_data['Games Played'] * 100
germany_data['Win Percentage'] = germany_data['Win'] / germany_data['Games Played'] * 100
brazil_data['Win Percentage'] = brazil_data['Win'] / brazil_data['Games Played'] * 100
uruguay_data['Win Percentage'] = uruguay_data['Win'] / uruguay_data['Games Played'] * 100
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13300\797903013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   england_data['Win Percentage'] = england_data['Win'] / england_data['Games Played'] * 100
# C:\Users\USER\AppData\Local\Temp\ipykernel_13300\797903013.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   germany_data['Win Percentage'] = germany_data['Win'] / germany_data['Games Played'] * 100
# ...

# %% [markdown]
# # win percentages of England, Germany, Brazil, Uruguay

# %%
              print('England')
print(england_data[['year', 'Win Percentage']])
              print('Germany')
print(germany_data[['year', 'Win Percentage']])
              print('Brazil')
print(brazil_data[['year', 'Win Percentage']])
              print('Uruguay')
print(uruguay_data[['year', 'Win Percentage']])
# Out:
# England
#      year  Win Percentage
# 4    2022       60.000000
# 35   2018       42.857143
# 89   2014        0.000000
# 108  2010       25.000000
# Germany
#     year  Win Percentage
# 16  2022       33.333333
# 50  2018       33.333333
# 64  2014       85.714286
# 98  2010       71.428571
# Brazil
#      year  Win Percentage
# 7    2022       60.000000
# 37   2018       60.000000
# 67   2014       42.857143
# 101  2010       60.000000
# Uruguay
#     year  Win Percentage
# 19  2022       33.333333
# 36  2018       80.000000
# 75  2014       50.000000
# 99  2010       42.857143

# %% [markdown]
# # Comparison between Germany, Brazil and Uruguay

# %%
combined_data = pd.concat([germany_data, brazil_data, uruguay_data])

# %%
sns.lineplot(x='year', y='Points', hue='Team', data=combined_data)
plt.title('Points Over Years for Germany, Brazil, and Uruguay')
plt.show()

# %% [markdown]
# # Goal record of Brazil

# %%
brazil_data['Avg Goals For'] = brazil_data['Goals For'] / brazil_data['Games Played']
brazil_data['Avg Goals Against'] = brazil_data['Goals Against'] / brazil_data['Games Played']
print(brazil_data[['year', 'Avg Goals For', 'Avg Goals Against']])
# Out:
#      year  Avg Goals For  Avg Goals Against
# 7    2022       1.600000                0.6
# 37   2018       1.600000                0.6
# 67   2014       1.571429                2.0
# 101  2010       1.800000                0.8
# C:\Users\USER\AppData\Local\Temp\ipykernel_13300\777424731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brazil_data['Avg Goals For'] = brazil_data['Goals For'] / brazil_data['Games Played']
# C:\Users\USER\AppData\Local\Temp\ipykernel_13300\777424731.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
